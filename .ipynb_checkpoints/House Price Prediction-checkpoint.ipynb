# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', None)
pd.set_option('max_rows', 90)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score

from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit
from sklearn.ensemble import GradientBoostingRegressor

# %%
train0 = pd.read_csv("dataset/train.csv")
test0 = pd.read_csv("dataset/test.csv")
sample_submission = pd.read_csv('dataset/sample_submission.csv')

# %% [markdown]
# ## What to do
# ### Nhan xet ve data:
# train0.shape: (1460, 81)
#
# test0.shape: (1459, 80)
#
# Trong 81 variables cua train0 co 43 variables la co dtypes 'object' (text, cat, ...) va 38 variables la dang number.
# ### Muc tieu:
# Thu duoc bo du lieu de co the su dung model Linear Regression
# ### 4 assumptions of Linear Regression:
# https://www.statology.org/linear-regression-assumptions/
#
# 1. exists linear relationship
# 2. residuals are independent
# 3. residuals have constant variance
# 4. normality
#
# ### Cac buoc de thu duoc bo data thoa man assumptions tren:
# 1. Lam sach data: missing values va outliers
# 2. scater plot (univariate) va heatmap (multivariate) quan sat moi tuong quan voi vien Target. Lay ra toi da M bien (M < 80) va adding important features
# 3. transform data:
# + target variable: xu li skewness de thoa man normality, scaling
# + features: voi cac numerical variables (xu li skewness, scaling); voi categorical (transform, encode)

# %%
# Out:
# (1460, 81)

# %% [markdown]
# # Step 1: Cleaning

# %% [markdown]
# ## Step 1.0: Combine Train and Test Sets
#
# Lua chon combine de tiet kiem thoi gian clean 2 lan va co nhieu du lieu hon de thay the missing data hoac kiem soat outliers.

# %%
target = train0['SalePrice']
test_ids = test0['Id']

train1 = train0.drop(['Id', 'SalePrice'], axis=1) 
test1 = test0.drop('Id', axis = 1)

data1 = pd.concat([train1, test1], axis=0)

# %% [markdown]
# ## Step 1.1: Missing values

# %%
total = data1.isnull().sum().sort_values(ascending=False)
percent = (data1.isnull().sum()/data1.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         2909  0.996574
# MiscFeature    2814  0.964029
# Alley          2721  0.932169
# Fence          2348  0.804385
# FireplaceQu    1420  0.486468
# LotFrontage     486  0.166495
# GarageCond      159  0.054471
# GarageQual      159  0.054471
# GarageYrBlt     159  0.054471
# GarageFinish    159  0.054471
# GarageType      157  0.053786
# BsmtCond         82  0.028092
# BsmtExposure     82  0.028092
# BsmtQual         81  0.027749
# BsmtFinType2     80  0.027407
# BsmtFinType1     79  0.027064
# MasVnrType       24  0.008222
# MasVnrArea       23  0.007879
# MSZoning          4  0.001370
# BsmtHalfBath      2  0.000685

# %% [markdown]
# #### Nhan xet
#
# 1. Cac columns co missing data > 15% -> drop
# 2. Cach xu ly missing data cua categorical values:
#
#  - quen khong nhap: xu li bang cach thay bang mode
#  - chu dich de trong, vi du GarageConde co gia tri NA tuc la No Garage. Luc nay thi nen thay NA thay text "None"
# 3. Cach xu ly missing data cua numerical values:
#  - Co ve se khong nhieu, ti nua se xu ly manually tung feature

# %% [markdown]
# #### Buoc 1: Drop columns co missing data > 15%

# %%
data2 = data1.copy()
data2.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage'], axis = 1, inplace = True)
object_na = pd.DataFrame(data2.select_dtypes('object').isna().sum() > 0)
object_na.index
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# #### Buoc 2: Xu ly Categorical Missing Values

# %%
# Nhom 1: Thay gia tri na = 'None'
for column in [
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond'
]:
    data2[column] = data2[column].fillna("None")

# Nhom 2: Thay cac gia tri Na = mode()
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %% [markdown]
# #### Buoc 3: Xu ly Numerical missing values

# %%
data3 = data2.copy()
col_has_missing = [data3.loc[:, data3.isna().sum() > 0].select_dtypes('number').columns]
col_has_missing
# Out:
# [Index(['MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#         'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars',
#         'GarageArea'],
#        dtype='object')]

# %%
missing_data.loc[['MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
        'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars',
        'GarageArea']]
# Out:
#               Total   Percent
# MasVnrArea       23  0.007879
# BsmtFinSF1        1  0.000343
# BsmtFinSF2        1  0.000343
# BsmtUnfSF         1  0.000343
# TotalBsmtSF       1  0.000343
# BsmtFullBath      2  0.000685
# BsmtHalfBath      2  0.000685
# GarageYrBlt     159  0.054471
# GarageCars        1  0.000343
# GarageArea        1  0.000343

# %% [markdown]
# - MasVnrArea(Masonry veneer area in square feet): drop vi co the dung nhieu bien sibling khac thay the -> drop
# - GarageYrBlt (Year garage was built): thuc te khong quan trong voi HousePrice -> drop
# - Cac bien con lai chi co 1, 2 missing values -> drop luon cac dong co missing values

# %%
data3.drop(['MasVnrArea', 'GarageYrBlt'], axis=1, inplace=True)
data4 = data3.copy()

# %%
set_col = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
           'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']
for col in set_col:
    data4 = data4.drop(data4.loc[data4[col].isnull()].index)
data4.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# ## Step 1.2: Outliers
#
# https://cxl.com/blog/outliers/
#
# Buoc 1: Detect outliers
#
# - Boxplot, IQR, SD
# - Scatter plot
#
#
# Buoc 2: Handling outliers
#
# - Transforming
# - Scaling
# - Imputing
# - Deleting
#
# Cai nay nam trong muc Feature Engineering!

# %%
data5 = data4.copy()
data5['MSSubClass'] = data5['MSSubClass'].astype(str)
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False)
skew_df
# Out:
#           Feature       Skew  Absolute Skew  Skewed
# 0         LotArea  12.926730      12.926730    True
# 1     OverallQual   0.196334       0.196334   False
# 2     OverallCond   0.572590       0.572590    True
# 3       YearBuilt  -0.601509       0.601509    True
# 4    YearRemodAdd  -0.451326       0.451326   False
# 5      BsmtFinSF1   1.423884       1.423884    True
# 6      BsmtFinSF2   4.141222       4.141222    True
# 7       BsmtUnfSF   0.919584       0.919584    True
# 8     TotalBsmtSF   1.168648       1.168648    True
# 9        1stFlrSF   1.402690       1.402690    True
# 10       2ndFlrSF   0.863022       0.863022    True
# 11   LowQualFinSF  12.076090      12.076090    True
# 12      GrLivArea   1.256109       1.256109    True
# 13   BsmtFullBath   0.624550       0.624550    True
# 14   BsmtHalfBath   3.926798       3.926798    True
# 15       FullBath   0.166886       0.166886   False
# 16       HalfBath   0.696084       0.696084    True
# 17   BedroomAbvGr   0.324624       0.324624   False
# 18   KitchenAbvGr   4.315501       4.315501    True
# 19   TotRmsAbvGrd   0.757895       0.757895    True
# 20     Fireplaces   0.733578       0.733578    True
# 21     GarageCars  -0.218073       0.218073   False
# 22     GarageArea   0.241677       0.241677   False
# 23     WoodDeckSF   1.841324       1.841324    True
# 24    OpenPorchSF   2.531275       2.531275    True
# 25  EnclosedPorch   4.025988       4.025988    True
# 26      3SsnPorch  11.364106      11.364106    True
# 27    ScreenPorch   3.941914       3.941914    True
# 28       PoolArea  16.880770      16.880770    True
# 29        MiscVal  21.924619      21.924619    True
# 30         MoSold   0.194923       0.194923   False
# 31         YrSold   0.133021       0.133021   False

# %%
# Xu li Skewed data bang cach dung log transform
for column in skew_df.query("Skewed == True")['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# # Step 2: Feature Engineering
#
# - Step 2.1: Log transform for Skewed Featured (already)
# - Step 2.2: Encode Categoricals
# - Step 2.3: Scaling

# %%
# Step 2.2
data6 = data5.copy()
data6 = pd.get_dummies(data6)

# %%
# Step 2.3
data7 = data6.copy()
scaler = StandardScaler()
scaler.fit(data6)
data7 = pd.DataFrame(scaler.transform(data7), index=data7.index, columns=data7.columns)

# %% [markdown]
# # Step3: Target Transformation

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
sns.distplot(target, kde=True, fit=scipy.stats.norm)
plt.title("Without Log Transform")

plt.subplot(1, 2, 2)
sns.distplot(np.log(target), kde=True, fit=scipy.stats.norm)
plt.xlabel("Log SalePrice")
plt.title("With Log Transform")

plt.show()

# %%
log_target = np.log(target)

# %% [markdown]
# # Step 4: Split data and Check correlation

# %%
data8 = data7.copy()
divided_row = train0.index.max()
train_8 = data8.loc[:divided_row, :].copy()
test_8 = data8.loc[divided_row:, :].reset_index(drop=True).copy()

# %%
data_train_8 = pd.concat([train_8, log_target], axis=1)
data_train_8.head()
# Out:
#     LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF1  \
# 0 -0.102668     0.645593    -0.434252   1.039674      0.896423    0.782432
# 1  0.147853    -0.063804     1.907196   0.160771     -0.396006    0.891665
# 2  0.459260     0.645593    -0.434252   0.974977      0.848555    0.657337
# 3  0.137600     0.645593    -0.434252  -1.869917     -0.683212    0.386063
# 4  0.924775     1.354991    -0.434252   0.942605      0.752820    0.757307
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0   -0.362988  -0.327885     0.015337 -0.777884  1.197248     -0.117054
# 1   -0.362988   0.012796     0.346764  0.426931 -0.863346     -0.117054
# 2   -0.362988   0.239587     0.076889 -0.554131  1.201502     -0.117054
# 3   -0.362988   0.356547    -0.090699 -0.418818  1.160090     -0.117054
# 4   -0.362988   0.304536     0.263685  0.124918  1.261114     -0.117054
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0
arageCond_Ex  GarageCond_Fa  GarageCond_Gd  GarageCond_None  \
# 0      -0.032108      -0.161448      -0.071944        -0.239479
# 1      -0.032108      -0.161448      -0.071944        -0.239479
# 2      -0.032108      -0.161448      -0.071944        -0.239479
# 3      -0.032108      -0.161448      -0.071944        -0.239479
# 4      -0.032108      -0.161448      -0.071944        -0.239479
#
#    GarageCond_Po  GarageCond_TA  PavedDrive_N  PavedDrive_P  PavedDrive_Y  \
# 0      -0.069493        0.31569        -0.283     -0.147468      0.324812
# 1      -0.069493        0.31569        -0.283     -0.147468      0.324812
# 2      -0.069493        0.31569        -0.283     -0.147468      0.324812
# 3      -0.069493        0.31569        -0.283     -0.147468      0.324812
# 4      -0.069493        0.31569        -0.283     -0.147468      0.324812
#
#    SaleType_COD  SaleType_CWD  SaleType_Con  SaleType_ConLD  SaleType_ConLI  \
# 0     -0.174416     -0.064316     -0.041466        -0.09304        -0.05567
# 1     -0.174416     -0.064316     -0.041466        -0.09304        -0.05567
# 2     -0.174416     -0.064316     -0.041466        -0.09304        -0.05567
# 3     -0.174416     -0.064316     -0.041466        -0.09304        -0.05567
# 4     -0.174416     -0.064316     -0.041466        -0.09304        -0.05567
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0       -0.052477     -0.298964      -0.04908     0.393746
# 1       -0.052477     -0.298964      -0.04908     0.393746
# 2       -0.052477     -0.298964      -0.04908     0.393746
# 3       -0.052477     -0.298964      -0.04908     0.393746
# 4       -0.052477     -0.298964      -0.04908     0.393746
#
#    SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0              -0.262661              -0.064316              -0.08921
# 1              -0.262661              -0.064316              -0.08921
# 2              -0.262661              -0.064316              -0.08921
# 3               3.807188              -0.064316              -0.08921
# 4              -0.262661              -0.064316              -0.08921
#
#    SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial  \
# 0             -0.126667              0.462878              -0.303033
# 1             -0.126667              0.462878              -0.303033
# 2             -0.126667              0.462878              -0.303033
# 3             -0.126667             -2.160397              -0.303033
# 4             -0.126667              0.462878              -0.303033
#
#    SalePrice
# 0  12.247694
# 1  12.109011
# 2  12.317167
# 3  11.849398
# 4  12.429216

# %%
#correlation matrix
corrmat = data_train_8.corr()
#saleprice correlation matrix
k = 20 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice']

'''
cm = np.corrcoef(data_train_8[cols].values.T)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
'''
# Out:
# '\ncm = np.corrcoef(data_train_8[cols].values.T)\nhm = sns.heatmap(cm, cbar=True, annot=True, square=True, yticklabels=cols.values, xticklabels=cols.values)\nplt.show()\n'

# %%
cols
# Out:
# SalePrice            1.000000
# OverallQual          0.817390
# GrLivArea            0.731093
# GarageCars           0.682652
# GarageArea           0.653310
# 1stFlrSF             0.611179
# FullBath             0.595621
# YearBuilt            0.584430
# YearRemodAdd         0.565419
# TotRmsAbvGrd         0.541530
# Foundation_PConc     0.531035
# ExterQual_Gd         0.509893
# Fireplaces           0.508460
# HeatingQC_Ex         0.466810
# BsmtQual_Ex          0.464170
# OpenPorchSF          0.460737
# BsmtFinType1_GLQ     0.440928
# GarageFinish_Fin     0.419077
# GarageType_Attchd    0.415591
# KitchenQual_Ex       0.414089
# Name: SalePrice, dtype: float64
